# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import missingno as msno
import plotly.graph_objects as go
import os
if os.path.split(os.getcwd())[-1]=='notebooks':
        os.chdir("../")
        

from datetime import datetime

# %% [markdown]
# # Styles and settings

# %%
# %matplotlib inline
sns.set(style='darkgrid')
mpl.rcParams['figure.figsize'] = (16,9)
pd.set_option('display.max_rows', 500)

# %%
#print (os.getcwd())

# %% [markdown]
# # Imports from the previous notebook

# %%
pd_raw = pd.read_csv('data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
data_raw['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
 country_list = pd_raw['location'].unique()  # has to copied from the previous notebook
data_analysis = pd.raw_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')
data_analysis.set_index(['date'], inplace=True)

# %%
data_analysis.tail()
# Out:
#            iso_code continent  location  total_cases  new_cases  \
# date
# 2022-07-23      ZWE    Africa  Zimbabwe     256246.0       29.0
# 2022-07-24      ZWE    Africa  Zimbabwe     256254.0        8.0
# 2022-07-25      ZWE    Africa  Zimbabwe     256270.0       16.0
# 2022-07-26      ZWE    Africa  Zimbabwe     256284.0       14.0
# 2022-07-27      ZWE    Africa  Zimbabwe     256315.0       31.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2022-07-23              23.286        5572.0         2.0                0.857
# 2022-07-24              24.429        5572.0         0.0                0.857
# 2022-07-25              26.714        5572.0         0.0                0.857
# 2022-07-26              13.857        5574.0         2.0                0.857
# 2022-07-27              18.286        5574.0         0.0                0.857
#
#             total_cases_per_million  ...  female_smokers  male_smokers  \
# ...

# %%
data_Relativecases= pd.DataFrame(data_analysis.index)
data_Relativecases.set_index(['date'], inplace=True)

# %%
for each in country_list:
    data_Relativecases[each] = pd.DataFrame(data_analysis[each+str('_Relativecases')])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Afghanistan_Relativecases'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
